# %%
import pandas as pd
import numpy as np
import matplotlib
df=pd.read_csv("pedestrian.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22945 entries, 0 to 22944
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          22945 non-null  int64
#  1   id                                  22945 non-null  float64
#  2   pedestrian_category                 22945 non-null  object
#  3   pedestrian_condition                22945 non-null  object
#  4   pedestrian_behaviour                19153 non-null  object
#  5   situation_at_the_point_of_accident  22945 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.head()
# Out:
#    Unnamed: 0            id pedestrian_category  \
# 0           0  2.100180e+09               Woman
# 1           1  2.100180e+09               Woman
# 2           2  2.100180e+09                 man
# 3           3  2.100180e+09                 man
# 4           4  2.100180e+09               Woman
#
#                                 pedestrian_condition  \
# 0  under the influence of alcohol with a blood al...
# 1           good no adverse circumstances were found
# 2  under the influence of alcohol with a blood al...
# 3                           inattention, distraction
# 4           good no adverse circumstances were found
#
#                                 pedestrian_behaviour  \
# 0  sudden entry into the roadway from the sidewal...
# 1                               correct, appropriate
# 2  sudden entry into the roadway from the sidewal...
# 3  sudden entry into the roadway from the sidewal...
# 4                               correct, appropriate
#
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0            id pedestrian_category  \
# 22940       22942  1.909090e+11                 man
# 22941       22943  1.909090e+11                 man
# 22942       22944  1.909090e+11                 man
# 22943       22945  1.909090e+11               Woman
# 22944       22946  1.909100e+11                 man
#
#                                     pedestrian_condition  \
# 22940                           inattention, distraction
# 22941  under the influence of alcohol with a blood al...
# 22942                           inattention, distraction
# 22943           good no adverse circumstances were found
# 22944                      other condition not specified
#
#                                     pedestrian_behaviour  \
# 22940  sudden entry into the roadway from the sidewal...
# 22941  sudden entry into the roadway from the sidewal...
# 22942  sudden entry into the roadway from the sidewal...
# 22943                               correct, appropriate
# ...

# %%
df
# Out:
#        Unnamed: 0            id pedestrian_category  \
# 0               0  2.100180e+09               Woman
# 1               1  2.100180e+09               Woman
# 2               2  2.100180e+09                 man
# 3               3  2.100180e+09                 man
# 4               4  2.100180e+09               Woman
# ...           ...           ...                 ...
# 22940       22942  1.909090e+11                 man
# 22941       22943  1.909090e+11                 man
# 22942       22944  1.909090e+11                 man
# 22943       22945  1.909090e+11               Woman
# 22944       22946  1.909100e+11                 man
#
#                                     pedestrian_condition  \
# 0      under the influence of alcohol with a blood al...
# 1               good no adverse circumstances were found
# 2      under the influence of alcohol with a blood al...
# 3                               inattention, distraction
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22945 entries, 0 to 22944
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          22945 non-null  int64
#  1   id                                  22945 non-null  float64
#  2   pedestrian_category                 22945 non-null  object
#  3   pedestrian_condition                22945 non-null  object
#  4   pedestrian_behaviour                19153 non-null  object
#  5   situation_at_the_point_of_accident  22945 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                               0
# id                                       0
# pedestrian_category                      0
# pedestrian_condition                     0
# pedestrian_behaviour                  3792
# situation_at_the_point_of_accident       0
# dtype: int64

# %%
df["pedestrian_category"]
# Out:
# 0        Woman
# 1        Woman
# 2          man
# 3          man
# 4        Woman
#          ...
# 22940      man
# 22941      man
# 22942      man
# 22943    Woman
# 22944      man
# Name: pedestrian_category, Length: 22945, dtype: object

# %%
df["pedestrian_condition"]
# Out:
# 0        under the influence of alcohol with a blood al...
# 1                 good no adverse circumstances were found
# 2        under the influence of alcohol with a blood al...
# 3                                 inattention, distraction
# 4                 good no adverse circumstances were found
#                                ...
# 22940                             inattention, distraction
# 22941    under the influence of alcohol with a blood al...
# 22942                             inattention, distraction
# 22943             good no adverse circumstances were found
# 22944                        other condition not specified
# Name: pedestrian_condition, Length: 22945, dtype: object

# %%
df["pedestrian_behaviour"]
# Out:
# 0        sudden entry into the roadway from the sidewal...
# 1                                     correct, appropriate
# 2        sudden entry into the roadway from the sidewal...
# 3        sudden entry into the roadway from the sidewal...
# 4                                     correct, appropriate
#                                ...
# 22940    sudden entry into the roadway from the sidewal...
# 22941    sudden entry into the roadway from the sidewal...
# 22942    sudden entry into the roadway from the sidewal...
# 22943                                 correct, appropriate
# 22944    poor estimation of the distance and speed of t...
# Name: pedestrian_behaviour, Length: 22945, dtype: object

# %%
df["situation_at_the_point_of_accident
"]
# Out:
#   Cell In[13], line 1
#     df["situation_at_the_point_of_accident
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df["situation_at_the_point_of_accident"]
# Out:
# 0                                        another situation
# 1                            crossing at a marked crossing
# 2                                        another situation
# 3                                        another situation
# 4                            crossing at a marked crossing
#                                ...
# 22940    crossing just in front of or behind a parked v...
# 22941    Crossing outside the crossing (20 metres or mo...
# 22942    Crossing outside the crossing (20 metres or mo...
# 22943    Crossing outside the crossing (20 metres or mo...
# 22944    Crossing outside the crossing (20 metres or mo...
# Name: situation_at_the_point_of_accident, Length: 22945, dtype: object

# %%
df["pedestrian_category"].unique()
# Out:
# array(['Woman', 'man', 'another group', 'child (up to 15 years)',
#        'group of children'], dtype=object)

# %%
df["pedestrian_category"].head()
# Out:
# 0    Woman
# 1    Woman
# 2      man
# 3      man
# 4    Woman
# Name: pedestrian_category, dtype: object

# %%
df["pedestrian_category"].head(50)
# Out:
# 0                      Woman
# 1                      Woman
# 2                        man
# 3                        man
# 4                      Woman
# 5                        man
# 6                      Woman
# 7              another group
# 8                      Woman
# 9     child (up to 15 years)
# 10                     Woman
# 11                       man
# 12                       man
# 13                       man
# 14    child (up to 15 years)
# 15                     Woman
# 16                     Woman
# 17             another group
# 18                     Woman
# 19                       man
# 20                       man
# 21                       man
# 22    child (up to 15 years)
# 23    child (up to 15 years)
# 24                     Woman
# 25             another group
# 26                     Woman
# 27    child (up to 15 years)
# 28                       man
# 29                     Woman
# 30                       man
# 31    child (up to 15 years)
# ...

# %%
df.loc[141:]
# Out:
#        Unnamed: 0            id pedestrian_category  \
# 141           141  2.100184e+09                 man
# 142           142  2.100184e+09                 man
# 143           143  2.100184e+09                 man
# 144           144  2.100184e+09               Woman
# 145           145  2.100184e+09               Woman
# ...           ...           ...                 ...
# 22940       22942  1.909090e+11                 man
# 22941       22943  1.909090e+11                 man
# 22942       22944  1.909090e+11                 man
# 22943       22945  1.909090e+11               Woman
# 22944       22946  1.909100e+11                 man
#
#                                     pedestrian_condition  \
# 141                             inattention, distraction
# 142                             inattention, distraction
# 143             good no adverse circumstances were found
# 144    under the influence of alcohol with a blood al...
# ...

# %%
len(df["pedestrian_category"].unique())
# Out:
# 5

# %%
df.loc[141:200]
# Out:
#      Unnamed: 0            id     pedestrian_category  \
# 141         141  2.100184e+09                     man
# 142         142  2.100184e+09                     man
# 143         143  2.100184e+09                     man
# 144         144  2.100184e+09                   Woman
# 145         145  2.100184e+09                   Woman
# 146         146  2.100184e+09                     man
# 147         147  2.100184e+09                     man
# 148         148  2.100184e+09                     man
# 149         149  2.100184e+09                     man
# 150         150  2.100184e+09                   Woman
# 151         151  2.100184e+09                     man
# 152         152  2.100184e+09                   Woman
# 153         153  2.100184e+09                     man
# 154         154  2.100184e+09           another group
# 155         155  2.100184e+09  child (up to 15 years)
# 156         156  2.100184e+09                   Woman
# ...

# %%
df.sample(20)
# Out:
#        Unnamed: 0            id     pedestrian_category  \
# 6724         6724  1.508060e+11                   Woman
# 5664         5664  6.020617e+10                     man
# 1140         1140  1.160618e+10                   Woman
# 1190         1190  2.010618e+10                   Woman
# 17706       17707  4.020619e+10  child (up to 15 years)
# 13634       13634  1.080616e+10                   Woman
# 18594       18595  7.010619e+10                     man
# 12668       12668  2.100161e+09                   Woman
# 848           848  1.040618e+10  child (up to 15 years)
# 16452       16453  2.100194e+09  child (up to 15 years)
# 20202       20203  3.100220e+09  child (up to 15 years)
# 7532         7532  2.100207e+09                     man
# 2866         2866  1.405060e+11                     man
# 17116       17117  1.070619e+10                   Woman
# 15218       15218  7.040616e+10                   Woman
# 18548       18549  6.130619e+10  child (up to 15 years)
# ...

# %%
df.sample(100)
# Out:
#        Unnamed: 0            id     pedestrian_category  \
# 18315       18316  6.020619e+10                     man
# 8004         8004  1.110620e+10                   Woman
# 8276         8276  3.050620e+10                   Woman
# 20770       20771  2.010622e+10  child (up to 15 years)
# 2591         2591  7.030618e+10                     man
# ...           ...           ...                     ...
# 1610         1610  4.030618e+10                   Woman
# 9284         9284  7.070620e+10                     man
# 1943         1943  5.040618e+10                     man
# 6476         6476  1.405060e+11  child (up to 15 years)
# 16336       16337  2.100190e+09                     man
#
#                                     pedestrian_condition  \
# 18315           good no adverse circumstances were found
# 8004            good no adverse circumstances were found
# 8276            good no adverse circumstances were found
# 20770           good no adverse circumstances were found
# ...

# %%
df=df.replace(' ',np.nan)

# %%
df
# Out:
#        Unnamed: 0            id pedestrian_category  \
# 0               0  2.100180e+09               Woman
# 1               1  2.100180e+09               Woman
# 2               2  2.100180e+09                 man
# 3               3  2.100180e+09                 man
# 4               4  2.100180e+09               Woman
# ...           ...           ...                 ...
# 22940       22942  1.909090e+11                 man
# 22941       22943  1.909090e+11                 man
# 22942       22944  1.909090e+11                 man
# 22943       22945  1.909090e+11               Woman
# 22944       22946  1.909100e+11                 man
#
#                                     pedestrian_condition  \
# 0      under the influence of alcohol with a blood al...
# 1               good no adverse circumstances were found
# 2      under the influence of alcohol with a blood al...
# 3                               inattention, distraction
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0            id     pedestrian_category  \
# 0           0  2.100180e+09                   Woman
# 1           1  2.100180e+09                   Woman
# 2           2  2.100180e+09                     man
# 3           3  2.100180e+09                     man
# 4           4  2.100180e+09                   Woman
# 5           5  2.100180e+09                     man
# 6           6  2.100180e+09                   Woman
# 7           7  2.100180e+09           another group
# 8           8  2.100180e+09                   Woman
# 9           9  2.100180e+09  child (up to 15 years)
#
#                                 pedestrian_condition  \
# 0  under the influence of alcohol with a blood al...
# 1           good no adverse circumstances were found
# 2  under the influence of alcohol with a blood al...
# 3                           inattention, distraction
# 4           good no adverse circumstances were found
# 5            under the influence of drugs, narcotics
# ...

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df["pedestrian_condition"].unique()
# Out:
# array(['under the influence of alcohol with a blood alcohol content of 1‰ or more',
#        'good no adverse circumstances were found',
#        'inattention, distraction',
#        'under the influence of drugs, narcotics', 'not detected',
#        'under the influence of alcohol with a blood alcohol content of up to 0.99 ‰',
#        'physical disability (illness, nausea, reduced mobility, etc.)',
#        'suicide attempt, suicide', 'other condition not specified',
#        'invalid'], dtype=object)

# %%
df["pedestrian_behaviour"].unique()
# Out:
# array(['sudden entry into the roadway from the sidewalk, shoulder',
#        'correct, appropriate',
#        'poor estimation of the distance and speed of the vehicle', nan,
#        'sudden entry into the road from a boarding or dividing island',
#        'confused, hasty, indecisive behaviour', 'Side impact',
#        'sudden change in walking direction',
#        'children playing on the road'], dtype=object)

# %%
df["situation_at_the_point_of_accident"]
# Out:
# 0                                        another situation
# 1                            crossing at a marked crossing
# 2                                        another situation
# 3                                        another situation
# 4                            crossing at a marked crossing
#                                ...
# 22940    crossing just in front of or behind a parked v...
# 22941    Crossing outside the crossing (20 metres or mo...
# 22942    Crossing outside the crossing (20 metres or mo...
# 22943    Crossing outside the crossing (20 metres or mo...
# 22944    Crossing outside the crossing (20 metres or mo...
# Name: situation_at_the_point_of_accident, Length: 22945, dtype: object

# %%
df["situation_at_the_point_of_accident"].unique()
# Out:
# array(['another situation', 'crossing at a marked crossing',
#        'Crossing outside the crossing (20 metres or more from the crossing)',
#        'pedestrian entering the roadway near the crosswalk (approx. within 20 m)',
#        'pedestrian entry on the signal FREE',
#        'walking, standing on the pavement',
#        'pedestrian entering on the STOP signal',
#        'walking on the right side',
#        'crossing just in front of or behind a vehicle at a bus stop',
#        'crossing just in front of or behind a parked vehicle',
#        'walking on the wrong side'], dtype=object)

# %%
df.to_csv('Updated_Pedestrian.csv',index=False)

# %%
df.head(10)
# Out:
#    Unnamed: 0            id     pedestrian_category  \
# 0           0  2.100180e+09                   Woman
# 1           1  2.100180e+09                   Woman
# 2           2  2.100180e+09                     man
# 3           3  2.100180e+09                     man
# 4           4  2.100180e+09                   Woman
# 5           5  2.100180e+09                     man
# 6           6  2.100180e+09                   Woman
# 7           7  2.100180e+09           another group
# 8           8  2.100180e+09                   Woman
# 9           9  2.100180e+09  child (up to 15 years)
#
#                                 pedestrian_condition  \
# 0  under the influence of alcohol with a blood al...
# 1           good no adverse circumstances were found
# 2  under the influence of alcohol with a blood al...
# 3                           inattention, distraction
# 4           good no adverse circumstances were found
# 5            under the influence of drugs, narcotics
# ...
